# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 157.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 134.0 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 167.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 149.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 79.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 144.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-07-18 15:06:32--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  51.6MB/s    in 2.9s
#
# 2025-07-18 15:06:36 (51.6 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
# Step 1: Drop missing values
df_cleaned = df['DatabaseWantToWorkWith'].dropna()

# Step 2: Split multiple values and explode
db_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count occurrences and get Top 5
top_5 = db_series.value_counts().head(5)

# Step 4: Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5.values, labels=top_5.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Databases Respondents Want to Work With')
plt.axis('equal')  # Makes the pie chart a circle
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
# Step 1: Drop missing values in DevType
df_cleaned = df['DevType'].dropna()

# Step 2: Split multiple roles and explode
roles_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count the roles and get the Top 5
top_5_roles = roles_series.value_counts().head(5)

# Step 4: Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_roles.values, labels=top_5_roles.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Developer Roles')
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
# Step 1: Drop missing values from the column
df_cleaned = df['OpSysProfessional use'].dropna()

# Step 2: Split multiple OS entries (e.g., "Windows;Linux") and explode into separate rows
os_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count and get the Top N (e.g., top 5 or all with significant usage)
top_os = os_series.value_counts().head(5)  # Change to .value_counts() for full list

# Step 4: Plot the Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(top_os.values, labels=top_os.index, autopct='%1.1f%%', startangle=140)
plt.title('Top Operating Systems Used Professionally')
plt.axis('equal')  # Makes the pie chart a circle
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
# Step 1: Drop missing values
df_cleaned = df['LanguageHaveWorkedWith'].dropna()

# Step 2: Split multiple languages and explode
lang_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count the top 5 programming languages
top_5_langs = lang_series.value_counts().head(5)

# Step 4: Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_langs.values, labels=top_5_langs.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.axis('equal')  # Ensures a circular pie
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
# Step 1: Drop missing values
df_cleaned = df['NEWCollabToolsHaveWorkedWith'].dropna()

# Step 2: Split multiple tools and explode into individual rows
tools_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count frequencies and get the Top 5
top_5_tools = tools_series.value_counts().head(5)

# Step 4: Plot the Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_tools.values, labels=top_5_tools.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Collaboration Tools Used Professionally')
plt.axis('equal')  # Ensures a circular pie chart
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
# Step 1: Drop missing values
df_cleaned = df['LanguageAdmired'].dropna()

# Step 2: Split multiple admired languages and explode into separate rows
admired_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count frequencies and get the Top 5 admired languages
top_5_admired = admired_series.value_counts().head(5)

# Step 4: Plot the Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(top_5_admired.values, labels=top_5_admired.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Admired Programming Languages')
plt.axis('equal')  # Ensures a circular pie chart
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
print(df.columns.tolist())
# Out:
# ['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'NEWCollabToolsAdmired', 'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith
# ...

# %%
##Write your code here
# Step 1: Drop missing values

df_cleaned = df['AIToolCurrently Using'].dropna()

# Step 2: Split multiple tools and explode into separate rows
ai_tools_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count tool usage and get the Top 5
top_5_ai_tools = ai_tools_series.value_counts().head(5)

# Step 4: Plot the Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_ai_tools.values, labels=top_5_ai_tools.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 AI Tools Developers Are Currently using')
plt.axis('equal')  # Keeps the pie chart circular
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
# Step 1: Drop missing values from the column
df_cleaned = df['WebframeWantToWorkWith'].dropna()

# Step 2: Split multiple frameworks (e.g., "React.js;Next.js") and explode into individual rows
frameworks_series = df_cleaned.str.split(';').explode().str.strip()

# Step 3: Count frequency of each framework and select the Top 5
top_5_frameworks = frameworks_series.value_counts().head(5)

# Step 4: Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_frameworks.values, labels=top_5_frameworks.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Web Frameworks Respondents Want to Work With')
plt.axis('equal')  # Ensures a perfect circle
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
